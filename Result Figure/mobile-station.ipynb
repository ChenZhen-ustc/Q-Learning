# %%
import numpy as np 
import matplotlib.pyplot as plt
import warnings
from scipy import interpolate

warnings.filterwarnings('ignore')
np.random.seed(19)

# %%
resolution = 10
length = 100

cluster = {}
number = {}
colour = {}
SIGMA = {}
u = {}
label = {}
#font = {'family': 'Palatino',}
font = {}

# %%
y2_SARSA = np.load('Log/SARSA')
y2_Q = np.load('Log/Q')

x = np.linspace(0,99,100)
best2 = np.ones(100)*506
average2 = np.ones(100)*173

# %%
fig, ax = plt.subplots(figsize=(5,5))
plt.xlim((0,100)) #设置坐标轴范围
plt.ylim((5,50))
plt.xticks(np.arange(0,100,10))
plt.yticks(np.arange(10,500,45))
plt.grid(ls='--',c='#D3D3D3')
# line1_SARSA, = ax.plot(x, y2_SARSA, label='SARSA performance', color='#1E90FF')
# line1_Q, = ax.plot(x, y2_Q, label='Q-Learning performance', color='#FF8C00')
line1_SARSA, = ax.plot(x, y2_SARSA, label='2 drone SARSA')
line1_Q, = ax.plot(x, y2_Q, label='2 drone Q-Learning')

line2, = ax.plot(x, best2, dashes=[6, 2], label='Theoretical best', color='#F08080')
line3, = ax.plot(x, average2, dashes=[6, 2], label='Random position', color='#20B2AA')
plt.xlabel('Episode',font)
plt.ylabel('Connected MS Percentage (%)',font)
ax.legend(loc='lower right', bbox_to_anchor=(1.02, 1),ncol=2)
plt.show()
fig.savefig('plots/2drone1050ms.eps',dpi=600,format='eps', bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-8667a695ea00> in <module>
#      16 ax.legend(loc='lower right', bbox_to_anchor=(1.02, 1),ncol=2)
#      17 plt.show()
# ---> 18 fig.savefig('plots/2drone1050ms.eps',dpi=600,format='eps', bbox_inches='tight')
#
# ~/opt/anaconda3/envs/changgang-python3.6/lib/python3.6/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
# ...
